# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A43.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09N03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28N03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N30.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07W07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W23.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F16S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A37.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03W04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N22.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02W03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A53.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A47.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F17S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F15A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N35.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A49.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A66.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N45.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A59.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F17S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F17A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F14W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03W03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22A08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20W06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A43.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S23.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F26S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N38.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S27.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S40.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F17S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A51.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A41.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F25A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A55.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A58.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21H10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A51.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N51.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22S13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01F02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06S08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N50.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S22.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A28.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23N12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F26F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A35.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F25N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S33.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F25A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09W03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A64.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02W05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A55.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A65.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A59.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F26N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F17W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N43.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F15A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21H11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A44.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S35.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S38.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A43.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A48.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A53.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S28.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A33.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A51.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A53.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A31.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F18A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S36.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S34.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A59.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F18N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01W03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12N11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A57.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20N14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09F02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01H06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A45.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N56.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A49.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A22.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A49.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A31.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S46.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A57.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N33.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W23.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A27.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N23.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A50.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A64.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13W02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S48.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S36.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N33.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N47.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S34.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A48.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06H09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F14N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A60.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F14S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F25A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A55.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21H07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A35.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N57.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F15N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06S06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N48.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F13A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F16F02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A37.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F27H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A34.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A61.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A57.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30A08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F25A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A37.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N31.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07W04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07W02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F31A08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22N03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F15N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06S07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N35.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A54.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24W18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09W04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F16S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F30S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24H19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S35.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F29N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24N13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A47.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N28.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21W02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01A19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N37.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F16S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A48.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F16F01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F17S06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07N03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A57.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A50.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S44.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01F03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A31.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F15A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A28.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F20W04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A22.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A56.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02S15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F22A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F12N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F19N34.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F02N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A50.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07A39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23H07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07H07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F01S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F05N55.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S31.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F23N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28A08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21S06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F06H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F28S08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F14N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F24A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F21A36.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F09A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F03S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F10A44.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F04A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F11N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/female/F07S19.wav
# ...
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M11H07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M39H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M47A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N64.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M53A22.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A53.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M29N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N27.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M29S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M19S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A40.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M52N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M36S06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M05S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M02N16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A45.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M56W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16W02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M08N09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03S18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M43A08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M05N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M52S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M46N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22N31.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16H07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N40.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A43.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16A09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N47.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A38.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M39H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M06N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M43W03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M05S13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M19A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M31N11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M27N15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M48N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N43.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M36S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25W10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A20.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M17N06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M37N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N49.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M24A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M11N03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M41H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M20A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M05A10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M56A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22N13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M53A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M29N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M40S03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M09A13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M07N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22N26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M55A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A26.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M18N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M31N12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M37N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A44.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44N13.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22N27.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M02A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22W02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M21W04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M09A12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M47N22.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M47A16.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M21W06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M15A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44N24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N39.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N40.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M51N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M02N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M46A03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N60.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A32.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M17N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N55.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26S04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28W02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44N12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M29A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M34A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M15A11.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M13H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M41H05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M08H04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M51N19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M05N17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A51.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M40A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M27N19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M55A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A45.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N76.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M55N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A30.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M40N34.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M51N14.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N79.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M55N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M07N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M20N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M40S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M27N21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M31W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N80.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M09A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M27N56.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22W01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M09A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M22A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M47N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M53A25.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M02A24.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A44.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M24A02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M02H02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M40A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N29.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M47A07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M03A18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28S05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M05N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M18A01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A15.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M20N04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M08H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16H09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M30N07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M20A06.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N68.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M21S01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M37N12.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N72.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44N17.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M02H03.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28A28.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26A33.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M16A05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N67.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M53N01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25N08.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25A49.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N18.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M12N02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M04N19.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M23H01.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M28N05.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M44H09.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M53N10.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M46A04.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M26A21.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M25W07.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M27N44.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M48S02.wav
# /kaggle/input/shemo-persian-speech-emotion-detection-database/male/M33A02.wav

# %% [markdown]
# # **1: Data Preprocessing and Augmentation**

# %% [markdown]
# ## **Preparing and Normalizing ShEMO Audio Data**

# %% [markdown]
# ## In this stage, WAV files are converted to Mel Spectrograms and normalized to stabilize model inputs, along with balanced data splitting and simple augmentation like noise addition to simulate real-world conditions.

# %%
# Install dependencies if needed (Kaggle usually has them)
# !pip install torchaudio scikit-learn

import torch
import torchaudio
from torchaudio.transforms import MelSpectrogram, AmplitudeToDB
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# Load ShEMO dataset from Kaggle input
data_path = '/kaggle/input/shemo-persian-speech-emotion-detection-database/'  # Adjust if needed

# Emotion mapping (based on filename like M01A01.wav where 4th char='A' for Anger)
emotion_codes = {'A': 0, 'S': 1, 'F': 2, 'H': 3, 'W': 4, 'N': 5}  # Anger, Sadness, Fear, Happiness, Surprise, Neutral

# Collect audio paths and labels
audio_paths = []
labels = []

for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith('.wav'):
            file_path = os.path.join(root, file)
            emotion_code = None
            if len(file) >= 6:  # e.g., M01A01.wav -> emotion_code = file[3]
                emotion_code = file[3]
            if emotion_code in emotion_codes:
                audio_paths.append(file_path)
                labels.append(emotion_codes[emotion_code])

# Encode labels
le = LabelEncoder()
labels_encoded = le.fit_transform(labels)
print(f"Total samples: {len(audio_paths)}")

# Split data: stratified by labels
train_paths, test_paths, train_labels, test_labels = train_test_split(audio_paths, labels_encoded, test_size=0.2, stratify=labels_encoded, random_state=42)
val_paths, test_paths, val_labels, test_labels = train_test_split(test_paths, test_labels, test_size=0.5, stratify=test_labels, random_state=42)

print(f"Train: {len(train_paths)}, Val: {len(val_paths)}, Test: {len(test_paths)}")

# Function to compute normalization stats
def compute_stats(dataset):
    specs = [dataset[i][0] for i in range(len(dataset))]
    specs = torch.stack(specs)
    mean = specs.mean()
    std = specs.std()
    return mean, std

# Basic noise augmentation
class AddNoise(object):
    def __init__(self, noise_level=0.005):
        self.noise_level = noise_level

    def __call__(self, spec):
        noise = torch.randn_like(spec) * self.noise_level
        return spec + noise

# Updated Dataset with normalization
class SHEMODataset(Dataset):
    def __init__(self, audio_paths, labels, transform=None, mean=0, std=1):
        self.audio_paths = audio_paths
        self.labels = labels
        self.transform = transform
        self.mel_spec = MelSpectrogram(sample_rate=16000, n_mels=128, n_fft=1024, hop_length=512)
        self.db_transform = AmplitudeToDB()
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.audio_paths)

    def __getitem__(self, idx):
        waveform, sr = torchaudio.load(self.audio_paths[idx])
        if sr != 16000:
            waveform = torchaudio.functional.resample(waveform, sr, 16000)
        spec = self.db_transform(self.mel_spec(waveform))  # [1, mels, time]
        spec = spec.squeeze(0)  # [mels, time]
        
        # Pad or truncate to fixed length (126 frames for ~4s)
        target_len = 126
        if spec.shape[1] > target_len:
            spec = spec[:, :target_len]
        elif spec.shape[1] < target_len:
            spec = torch.nn.functional.pad(spec, (0, target_len - spec.shape[1]))
        
        # Normalize
        spec = (spec - self.mean) / (self.std + 1e-8)
        
        if self.transform:
            spec = self.transform(spec)
        
        # Debug print (remove after first run)
        if idx < 3:
            print(f"Sample {idx} shape: {spec.shape}")
        
        return spec, torch.tensor(self.labels[idx])

# Compute stats on temp train (without transform)
temp_train_ds = SHEMODataset(train_paths, train_labels)
train_mean, train_std = compute_stats(temp_train_ds)
print(f"Train Mean: {train_mean:.4f}, Std: {train_std:.4f}")

# Recreate datasets
train_transform = AddNoise()
train_ds = SHEMODataset(train_paths, train_labels, transform=train_transform, mean=train_mean, std=train_std)
val_ds = SHEMODataset(val_paths, val_labels, mean=train_mean, std=train_std)
test_ds = SHEMODataset(test_paths, test_labels, mean=train_mean, std=train_std)

# DataLoaders
batch_size = 32
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=batch_size)
test_loader = DataLoader(test_ds, batch_size=batch_size)

# Class weights for imbalance
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Class weights: {class_weights}")
# Out:
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchaudio) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchaudio) (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchaudio) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.3->scikit-learn) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Total samples: 3000
# Train: 2400, Val: 300, Test: 300
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Train Mean: -10.9931, Std: 17.2507
# Class weights: tensor([ 0.4723,  1.1142, 12.9032,  2.4845,  2.2222,  0.4866], device='cuda:0')

# %% [markdown]
# # **2: Model Training with SpecAugment**

# %% [markdown]
# ## **Training a Deep CNN with Robustness Techniques**

# %% [markdown]
# ## A three-layer CNN (featuring BatchNorm and Global Avg Pooling) is trained on spectrograms, with SpecAugment masking time and frequency dimensions to build noise resilience.

# %%
from torch import nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR

# Milder SpecAugment
class SpecAugment(nn.Module):
    def __init__(self, freq_mask_param=15, time_mask_param=50, num_masks=1):  # Reduced params
        super().__init__()
        self.freq_mask_param = freq_mask_param
        self.time_mask_param = time_mask_param
        self.num_masks = num_masks

    def forward(self, spec):
        for _ in range(self.num_masks):
            f = int(torch.rand(1).item() * self.freq_mask_param)
            f0 = int(torch.rand(1).item() * (spec.shape[0] - f))
            if f > 0 and f0 + f <= spec.shape[0]:
                spec[f0:f0 + f, :] = 0

            t = int(torch.rand(1).item() * self.time_mask_param)
            t0 = int(torch.rand(1).item() * (spec.shape[1] - t))
            if t > 0 and t0 + t <= spec.shape[1]:
                spec[:, t0:t0 + t] = 0
        return spec

# Deeper CNN (3 conv + GAP)
class SER_CNN(nn.Module):
    def __init__(self, num_classes=6):
        super().__init__()
        self.spec_aug = SpecAugment()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)  # New layer
        self.bn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(2, 2)
        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP for variable size
        self.dropout = nn.Dropout(0.25)  # Slightly less
        self.fc1 = nn.Linear(128, 128)  # After GAP: 128 features
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        batch_size = x.shape[0]
        x = x.unsqueeze(1)  # [batch, 1, mels, time]
        if self.training:
            x = self.spec_aug(x)
        
        x = self.pool(nn.ReLU()(self.bn1(self.conv1(x))))
        x = self.pool(nn.ReLU()(self.bn2(self.conv2(x))))
        x = self.pool(nn.ReLU()(self.bn3(self.conv3(x))))  # New
        x = self.global_pool(x)  # [batch, 128, 1, 1]
        x = self.dropout(x.view(batch_size, -1))
        x = nn.ReLU()(self.fc1(x))
        x = self.fc2(x)
        return x

# Setup with AdamW and Cosine scheduler
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SER_CNN(num_classes=6).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)  # AdamW + higher LR
scheduler = CosineAnnealingLR(optimizer, T_max=50, eta_min=1e-6)  # Smooth decay

# Train/Validate functions (same, but limited debug)
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    for specs, labels in loader:
        specs, labels = specs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(specs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(loader)

def validate(model, loader, criterion, device, epoch):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        debug_shown = False
        for batch_idx, (specs, labels) in enumerate(loader):
            specs, labels = specs.to(device), labels.to(device)
            outputs = model(specs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            # Limited debug: only epochs 1,5,10
            if epoch in [1,5,10] and not debug_shown and batch_idx == 0:
                print(f"Epoch {epoch} Val first batch preds: {predicted[:5].cpu().numpy()}")
                print(f"Epoch {epoch} Val first batch labels: {labels[:5].cpu().numpy()}")
                print(f"Epoch {epoch} Val outputs mean: {outputs.mean().item():.4f}")
                debug_shown = True
    
    return running_loss / len(loader), correct / total

# Train loop (num_epochs=50, but early stop patience=15 for more room)
num_epochs = 50
best_acc = 0
patience = 15  # Increased for slow start
counter = 0
for epoch in range(num_epochs):
    train_loss = train_epoch(model, train_loader, optimizer, criterion, device)
    val_loss, val_acc = validate(model, val_loader, criterion, device, epoch+1)
    scheduler.step()
    print(f"Epoch {epoch+1}: Train Loss {train_loss:.4f}, Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")
    
    if val_acc > best_acc:
        best_acc = val_acc
        counter = 0
        torch.save(model.state_dict(), '/kaggle/working/best_model.pth')
        print(f"New best acc: {best_acc:.4f}")
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping!")
            break
# Out:
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 1 Val first batch preds: [1 0 1 0 0]
# Epoch 1 Val first batch labels: [0 5 5 5 0]
# Epoch 1 Val outputs mean: -0.0313
# Epoch 1: Train Loss 1.7025, Val Loss 1.5560, Val Acc 0.4033
# New best acc: 0.4033
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 2: Train Loss 1.6456, Val Loss 1.5754, Val Acc 0.4133
# New best acc: 0.4133
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 3: Train Loss 1.6155, Val Loss 1.5656, Val Acc 0.5433
# New best acc: 0.5433
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 4: Train Loss 1.5982, Val Loss 1.5046, Val Acc 0.5300
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 5 Val first batch preds: [1 5 1 5 0]
# Epoch 5 Val first batch labels: [0 5 5 5 0]
# Epoch 5 Val outputs mean: -0.2208
# Epoch 5: Train Loss 1.5612, Val Loss 1.5032, Val Acc 0.4733
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 6: Train Loss 1.5614, Val Loss 1.5267, Val Acc 0.5200
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 7: Train Loss 1.5417, Val Loss 1.3902, Val Acc 0.5500
# New best acc: 0.5500
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 8: Train Loss 1.5077, Val Loss 2.4032, Val Acc 0.4267
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 9: Train Loss 1.5402, Val Loss 1.3867, Val Acc 0.4700
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 10 Val first batch preds: [0 5 5 5 3]
# Epoch 10 Val first batch labels: [0 5 5 5 0]
# Epoch 10 Val outputs mean: -0.2374
# Epoch 10: Train Loss 1.5305, Val Loss 1.4399, Val Acc 0.5767
# New best acc: 0.5767
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 11: Train Loss 1.4810, Val Loss 1.3791, Val Acc 0.5433
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 12: Train Loss 1.4772, Val Loss 1.4515, Val Acc 0.5167
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 13: Train Loss 1.4640, Val Loss 1.4545, Val Acc 0.4767
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 14: Train Loss 1.4611, Val Loss 1.5898, Val Acc 0.4933
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 15: Train Loss 1.4754, Val Loss 1.3966, Val Acc 0.4300
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 16: Train Loss 1.4284, Val Loss 1.3662, Val Acc 0.5867
# New best acc: 0.5867
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 17: Train Loss 1.4419, Val Loss 1.3586, Val Acc 0.6033
# New best acc: 0.6033
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 18: Train Loss 1.4124, Val Loss 1.3172, Val Acc 0.6600
# New best acc: 0.6600
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 19: Train Loss 1.4390, Val Loss 1.4203, Val Acc 0.5467
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 20: Train Loss 1.4240, Val Loss 1.2933, Val Acc 0.6167
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 21: Train Loss 1.4076, Val Loss 1.5150, Val Acc 0.6033
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 22: Train Loss 1.3869, Val Loss 2.3621, Val Acc 0.4400
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 23: Train Loss 1.4230, Val Loss 1.3555, Val Acc 0.6433
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 24: Train Loss 1.4013, Val Loss 1.2639, Val Acc 0.6867
# New best acc: 0.6867
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 25: Train Loss 1.3916, Val Loss 1.2977, Val Acc 0.5967
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 26: Train Loss 1.3911, Val Loss 1.4930, Val Acc 0.4300
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 27: Train Loss 1.3691, Val Loss 1.2658, Val Acc 0.6600
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 28: Train Loss 1.3370, Val Loss 1.3934, Val Acc 0.5433
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 29: Train Loss 1.3591, Val Loss 1.4197, Val Acc 0.4300
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 30: Train Loss 1.3360, Val Loss 1.3077, Val Acc 0.6100
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 31: Train Loss 1.3204, Val Loss 1.3333, Val Acc 0.5133
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 32: Train Loss 1.3387, Val Loss 1.3778, Val Acc 0.6900
# New best acc: 0.6900
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 33: Train Loss 1.2993, Val Loss 1.3680, Val Acc 0.4933
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 34: Train Loss 1.3529, Val Loss 1.3180, Val Acc 0.5867
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 35: Train Loss 1.2750, Val Loss 1.2829, Val Acc 0.6267
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 36: Train Loss 1.2974, Val Loss 1.2713, Val Acc 0.6233
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 37: Train Loss 1.2800, Val Loss 1.3588, Val Acc 0.5600
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 38: Train Loss 1.2695, Val Loss 1.2495, Val Acc 0.6600
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 39: Train Loss 1.2597, Val Loss 1.2519, Val Acc 0.6367
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 40: Train Loss 1.2635, Val Loss 1.2886, Val Acc 0.6433
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 41: Train Loss 1.2857, Val Loss 1.2633, Val Acc 0.6233
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 42: Train Loss 1.2589, Val Loss 1.2908, Val Acc 0.6167
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 43: Train Loss 1.2548, Val Loss 1.2686, Val Acc 0.6400
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 44: Train Loss 1.2643, Val Loss 1.3741, Val Acc 0.6600
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 45: Train Loss 1.2297, Val Loss 1.2550, Val Acc 0.6267
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 46: Train Loss 1.2734, Val Loss 1.2679, Val Acc 0.6333
# Sample 2 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Epoch 47: Train Loss 1.2283, Val Loss 1.2591, Val Acc 0.6367
# Early stopping!

# %% [markdown]
# # **3: Ensemble and Evaluation**

# %% [markdown]
# ## **Combining Models and Analyzing Final Performance**

# %% [markdown]
# ## An LSTM is trained on MFCC features and ensembled with the CNN via soft voting to minimize variance and boost robustness, yielding 69% Test Acc and 66.8% F1-score.

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch.nn.functional as F  # For pad

# MFCC transform (with n_mels=40 to suppress warning)
mfcc_transform = torchaudio.transforms.MFCC(sample_rate=16000, n_mfcc=13, melkwargs={'n_mels': 40})

# Updated MFCC Dataset (labels as tensor)
class SHEMODataset_MFCC(Dataset):
    def __init__(self, audio_paths, labels, mean=0, std=1):
        self.audio_paths = audio_paths
        self.labels = labels
        self.mfcc = mfcc_transform
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.audio_paths)

    def __getitem__(self, idx):
        waveform, sr = torchaudio.load(self.audio_paths[idx])
        if sr != 16000:
            waveform = torchaudio.functional.resample(waveform, sr, 16000)
        mfcc = self.mfcc(waveform).squeeze(0).transpose(0,1)  # [time, mfcc]
        
        # Pad/truncate to 100 frames
        target_len = 100
        if mfcc.shape[0] > target_len:
            mfcc = mfcc[:target_len]
        elif mfcc.shape[0] < target_len:
            pad_size = (0, 0, 0, target_len - mfcc.shape[0])  # Pad on time dim
            mfcc = F.pad(mfcc, pad_size)
        
        # Normalize (mean/std are scalars, broadcast)
        mfcc = (mfcc - self.mean) / (self.std + 1e-8)
        
        return mfcc, torch.tensor(self.labels[idx])

# Compute MFCC stats (reuse compute_stats, but ensure tensors)
def compute_stats(dataset):
    specs = [dataset[i][0] for i in range(len(dataset))]
    specs = torch.stack(specs)
    mean = specs.mean()
    std = specs.std()
    return mean, std

temp_mfcc_train = SHEMODataset_MFCC(train_paths, train_labels)
mfcc_mean, mfcc_std = compute_stats(temp_mfcc_train)
print(f"MFCC Mean: {mfcc_mean:.4f}, Std: {mfcc_std:.4f}")

# Create MFCC datasets
train_ds_mfcc = SHEMODataset_MFCC(train_paths, train_labels, mean=mfcc_mean, std=mfcc_std)
val_ds_mfcc = SHEMODataset_MFCC(val_paths, val_labels, mean=mfcc_mean, std=mfcc_std)
test_ds_mfcc = SHEMODataset_MFCC(test_paths, test_labels, mean=mfcc_mean, std=mfcc_std)

train_loader_mfcc = DataLoader(train_ds_mfcc, batch_size=32, shuffle=True)
val_loader_mfcc = DataLoader(val_ds_mfcc, batch_size=32)
test_loader_mfcc = DataLoader(test_ds_mfcc, batch_size=32)

# LSTM Model (same)
class SER_LSTM(nn.Module):
    def __init__(self, input_size=13, hidden_size=128, num_classes=6):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size*2, num_classes)

    def forward(self, x):
        _, (h_n, _) = self.lstm(x)
        h_n = torch.cat((h_n[0], h_n[1]), dim=1)
        return self.fc(h_n)

# Train LSTM (fixed: pass epoch to validate, limited debug)
lstm_model = SER_LSTM().to(device)
optimizer_lstm = optim.Adam(lstm_model.parameters(), lr=0.0001)
for epoch in range(20):
    train_loss = train_epoch(lstm_model, train_loader_mfcc, optimizer_lstm, criterion, device)
    val_loss, val_acc = validate(lstm_model, val_loader_mfcc, criterion, device, epoch+1)  # Fixed: pass epoch
    print(f"LSTM Epoch {epoch+1}: Train Loss {train_loss:.4f}, Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")
torch.save(lstm_model.state_dict(), '/kaggle/working/lstm_model.pth')

# Load CNN model (ensure it's the deeper one if updated)
cnn_model = SER_CNN(num_classes=6).to(device)  # Use the class from updated Stage 2
cnn_model.load_state_dict(torch.load('/kaggle/working/best_model.pth'))
lstm_model.load_state_dict(torch.load('/kaggle/working/lstm_model.pth'))

# Ensemble prediction (same)
def ensemble_predict(cnn_model, lstm_model, loader_spec, loader_mfcc, device):
    cnn_model.eval()
    lstm_model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for (specs, labels_spec), (mfccs, labels_mfcc) in zip(loader_spec, loader_mfcc):
            specs, mfccs = specs.to(device), mfccs.to(device)
            cnn_out = nn.Softmax(dim=1)(cnn_model(specs))
            lstm_out = nn.Softmax(dim=1)(lstm_model(mfccs))
            ensemble_out = (cnn_out + lstm_out) / 2
            preds = torch.argmax(ensemble_out, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels_spec.cpu().numpy())
    return all_preds, all_labels

# Evaluate on test set
test_preds, test_labels = ensemble_predict(cnn_model, lstm_model, test_loader, test_loader_mfcc, device)
acc = accuracy_score(test_labels, test_preds)
f1 = f1_score(test_labels, test_preds, average='weighted')
print(f"Ensemble Test Accuracy: {acc:.4f}, F1-Score: {f1:.4f}")

# Confusion Matrix
cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig('/kaggle/working/confusion_matrix.png')
plt.show()
# Out:
# MFCC Mean: -6.7302, Std: 36.5909
# Epoch 1 Val first batch preds: [0 0 1 0 0]
# Epoch 1 Val first batch labels: [0 5 5 5 0]
# Epoch 1 Val outputs mean: 0.0460
# LSTM Epoch 1: Train Loss 1.7897, Val Loss 1.7709, Val Acc 0.3733
# LSTM Epoch 2: Train Loss 1.7755, Val Loss 1.7623, Val Acc 0.4167
# LSTM Epoch 3: Train Loss 1.7591, Val Loss 1.7462, Val Acc 0.4233
# LSTM Epoch 4: Train Loss 1.7429, Val Loss 1.7255, Val Acc 0.4567
# Epoch 5 Val first batch preds: [0 0 5 0 0]
# Epoch 5 Val first batch labels: [0 5 5 5 0]
# Epoch 5 Val outputs mean: 0.0576
# LSTM Epoch 5: Train Loss 1.7040, Val Loss 1.6802, Val Acc 0.5167
# LSTM Epoch 6: Train Loss 1.6580, Val Loss 1.6279, Val Acc 0.5533
# LSTM Epoch 7: Train Loss 1.6156, Val Loss 1.5926, Val Acc 0.5867
# LSTM Epoch 8: Train Loss 1.5563, Val Loss 1.5940, Val Acc 0.5233
# LSTM Epoch 9: Train Loss 1.4998, Val Loss 1.5809, Val Acc 0.5100
# Epoch 10 Val first batch preds: [0 5 5 5 0]
# Epoch 10 Val first batch labels: [0 5 5 5 0]
# Epoch 10 Val outputs mean: 0.0848
# LSTM Epoch 10: Train Loss 1.5028, Val Loss 1.5428, Val Acc 0.4933
# LSTM Epoch 11: Train Loss 1.4420, Val Loss 1.5638, Val Acc 0.5333
# LSTM Epoch 12: Train Loss 1.4557, Val Loss 1.5263, Val Acc 0.5133
# LSTM Epoch 13: Train Loss 1.4263, Val Loss 1.5184, Val Acc 0.5567
# LSTM Epoch 14: Train Loss 1.4131, Val Loss 1.5068, Val Acc 0.5500
# LSTM Epoch 15: Train Loss 1.4059, Val Loss 1.5115, Val Acc 0.5233
# LSTM Epoch 16: Train Loss 1.3977, Val Loss 1.5164, Val Acc 0.5367
# LSTM Epoch 17: Train Loss 1.3966, Val Loss 1.5261, Val Acc 0.5367
# LSTM Epoch 18: Train Loss 1.3845, Val Loss 1.5176, Val Acc 0.5200
# LSTM Epoch 19: Train Loss 1.3704, Val Loss 1.5396, Val Acc 0.5433
# LSTM Epoch 20: Train Loss 1.3662, Val Loss 1.5627, Val Acc 0.5567
# Sample 0 shape: torch.Size([128, 126])
# Sample 1 shape: torch.Size([128, 126])
# Sample 2 shape: torch.Size([128, 126])
# Ensemble Test Accuracy: 0.6900, F1-Score: 0.6678
